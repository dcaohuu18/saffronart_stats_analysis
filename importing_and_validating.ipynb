# %%
import numpy as np
import pandas as pd

pd.options.display.float_format = '{:.1f}'.format # change the display format of numbers

# %%
saffronart_df = pd.read_csv('saffronart_dataset.csv') 

# change the dates to Pandas datetime objects:
saffronart_df['auction_date'] = pd.to_datetime(saffronart_df['auction_date'])
saffronart_df['birth_date'] = pd.to_datetime(saffronart_df['birth_date'])
saffronart_df['death_date'] = pd.to_datetime(saffronart_df['death_date'])

saffronart_df.head(5)
# Out:
#      artist birth_date birth_place death_date  artist_age  \
# 0  akhilesh 1956-01-01      Indore        NaT        63.0
# 1  akhilesh 1956-01-01      Indore        NaT        63.0
# 2  akhilesh 1956-01-01      Indore        NaT        63.0
# 3  akhilesh 1956-01-01      Indore        NaT        63.0
# 4  akhilesh 1956-01-01      Indore        NaT        63.0
#
#                              title  winning_bid  low_est  high_est  \
# 0              Divine Conversation       9000.0   5000.0    7000.0
# 1  In search of Untitled forms -II       1120.0   5000.0    6670.0
# 2      In Search of Untitled Lines       6186.0   6900.0    8625.0
# 3                          Magadhi       2400.0   5770.0    7695.0
# 4                         Untitled       2942.0   6735.0    8655.0
#
#   auction_date  category     style             size               medium
# 0   2019-06-01  painting  abstract   71.5 x 71.5 in   acrylic on canvas
# 1   2013-11-01  painting  abstract     32.5 x 44 in   acrylic on canvas
# 2   2013-08-01  painting       NaN       47 x 47 in   acrylic on canvas
# 3   2013-02-01  painting  abstract     33 x 44.5 in   acrylic on canvas
# 4   2013-02-01  painting  abstract       40 x 40 in   acrylic on canvas

# %%
saffronart_df.tail(5)
# Out:
#                  artist birth_date                            birth_place  \
# 12416       atul dodiya 1959-01-20                                 Mumbai
# 12417        m f husain 1913-09-17                Pandharpur, Maharashtra
# 12418  nasreen mohamedi 1937-01-01        Karachi India (now in Pakistan)
# 12419     baiju parthan 1956-01-01                       Kottayam, Kerala
# 12420   thota vaikuntam 1942-01-01  Boorugupali Karimnagar Andhra Pradesh
#
#       death_date  artist_age              title  winning_bid  low_est  \
# 12416        NaT        60.0        Walking Man      30475.0  20000.0
# 12417 2011-06-09        98.0           Untitled     340000.0 166670.0
# 12418 1990-01-01        53.0           Untitled      11352.0   8700.0
# 12419        NaT        63.0  Process - (Fruit)       4426.0   2460.0
# 12420        NaT        77.0           Untitled      26554.0  11115.0
#
#        high_est auction_date      category       style             size  \
# 12416   26670.0   2010-09-01      painting  figurative       21 x 21 in
# 12417  250000.0   2014-09-04      painting  figurative      118 x 46 in
# 12418   10870.0   2011-09-01       drawing    abstract   10.5 x 13.5 in
# 12419    4100.0   2015-04-07  print making  still life   36.5 x 34.5 in
# 12420   13335.0   2010-09-01      painting  figurative       36 x 24 in
#
#                                             medium
# 12416                                oil on paper
# 12417                               oil on canvas
# 12418                ink and pencil on card paper
# 12419   archival ink on hahnemuhle archival paper
# 12420                     acrylic on canvas board

# %%
# check outliers:

oldest_artist = saffronart_df.iloc[saffronart_df.artist_age.idxmax()]['artist': 'artist_age']
print("OLDEST ARTIST:", oldest_artist, sep = '\n')

youngest_artist = saffronart_df.iloc[saffronart_df.artist_age.idxmin()]['artist': 'artist_age']
print("\nYOUNGEST ARTIST:", youngest_artist, sep = '\n')

most_exp_lot = saffronart_df.iloc[saffronart_df.winning_bid.idxmax()] 
print("\nMOST EXPENSIVE LOT:", most_exp_lot, sep = '\n')

cheapest_lot = saffronart_df.iloc[saffronart_df.winning_bid.idxmin()] 
print("\nCHEAPEST LOT:", cheapest_lot, sep = '\n')
# Out:
# OLDEST ARTIST:
# artist            devayani krishna
# birth_date     1918-07-08 00:00:00
# birth_place                    NaN
# death_date                     NaT
# artist_age                   101.0
# Name: 5555, dtype: object
#
# YOUNGEST ARTIST:
# artist             girish dahiwale
# birth_date     1974-01-01 00:00:00
# birth_place                    NaN
# death_date     1998-01-01 00:00:00
# artist_age                    24.0
# Name: 2083, dtype: object
#
# MOST EXPENSIVE LOT:
# artist                   tyeb mehta
# birth_date      1925-01-01 00:00:00
# birth_place                     NaN
# death_date      2009-01-01 00:00:00
# artist_age                     84.0
# title                          Kali
# winning_bid               3998000.0
# low_est                   3000000.0
# high_est                  4000000.0
# auction_date    2018-06-01 00:00:00
# category                   painting
# style                    figurative
# size                     67 x 54 in
# medium               oil on canvas
# Name: 6427, dtype: object
#
# CHEAPEST LOT:
# artist                                                kriti arora
# birth_date                                    1972-01-01 00:00:00
# birth_place                                                   NaN
# death_date                                                    NaT
# artist_age                                                   47.0
# title           A) VIMILA MEHRA AND SUSPECT B) CRIME WOMEN CEL...
# winning_bid                                                  30.0
# low_est                                                     310.0
# high_est                                                    385.0
# auction_date                                  2015-10-01 00:00:00
# category                                                      NaN
# style                                                         NaN
# size                                                   12 x 19 in
# medium                                         colour photograph
# Name: 441, dtype: object

# %% [markdown]
# ###### I checked these records on saffronart.com and they're all correct.

# %%
# number of lots by auction date: 

lots_number = saffronart_df.auction_date.value_counts()
lots_number = lots_number.to_frame()

lots_number.reset_index(inplace = True)
lots_number.rename(columns = {'index': 'auction_date', 'auction_date': 'lots_number'}, inplace = True)
lots_number['day_of_week'] = pd.Series(lots_number['auction_date']).dt.dayofweek

lots_number
# Out:
#     auction_date  lots_number  day_of_week
# 0     2002-05-01          205            2
# 1     2001-12-01          194            5
# 2     2012-07-01          194            6
# 3     2018-12-01          187            5
# 4     2005-12-01          177            3
# 5     2014-12-01          176            0
# 6     2015-08-01          173            5
# 7     2015-03-01          173            6
# 8     2015-07-01          172            2
# 9     2002-12-01          169            6
# 10    2018-07-01          163            6
# 11    2015-10-01          155            3
# 12    2012-11-01          151            3
# 13    2018-01-01          147            0
# 14    2018-06-01          145            4
# 15    2014-03-01          140            5
# 16    2014-08-01          139            4
# 17    2013-09-01          139            6
# 18    2008-03-01          138            5
# 19    2006-12-01          137            4
# 20    2016-12-01          135            3
# 21    2016-11-01          134            1
# 22    2006-09-01          132            4
# 23    2007-03-01          132            3
# 24    2018-11-01          129            3
# 25    2006-05-01          129            0
# 26    2005-05-01          129            6
# 27    2008-09-01          128            0
# 28    2014-02-15          128            5
# 29    2017-04-01          125            5
# ..           ...          ...          ...
# 118   2016-05-01           41            6
# 119   2015-02-01           40            6
# 120   2019-01-18           40            4
# 121   2005-03-01           39            1
# 122   2016-02-01           38            0
# 123   2018-10-01           36            0
# 124   2018-08-01           31            2
# 125   2015-04-15           30            2
# 126   2008-11-01           30            5
# 127   2015-09-01           24            1
# 128   2014-09-01           17            0
# 129   2018-11-20           10            1
# 130   2019-01-15            8            1
# 131   2018-11-06            8            1
# 132   2019-02-12            6            1
# 133   2019-03-12            6            1
# 134   2019-02-19            5            1
# 135   2019-01-29            5            1
# 136   2018-12-11            5            1
# 137   2019-02-26            5            1
# 138   2018-11-13            3            1
# 139   2018-12-04            3            1
# 140   2018-11-27            3            1
# 141   2018-10-16            1            1
# 142   2018-10-30            1            1
# 143   2018-10-09            1            1
# 144   2019-01-08            1            1
# 145   2018-10-02            1            1
# 146   2018-10-23            1            1
# 147   2019-02-05            1            1
#
# [148 rows x 3 columns]

# %% [markdown]
# We notice that the auction dates on which only one or a few lots are for sale are all Tuesdays (0 is Monday and 6 is Sunday). This is a series of events called "Absolute Tuesdays" by StoryLTD. The numbers of lots for sale at these events vary and sometimes there's only one art piece open for sale. For auction dates with more lots, it's hard to check because Saffronart.com only lists the lots that actually got sold when grouping them by auction. Also, when cleaning the data, we remove lots that are not paintings.
