# %%
import numpy as np
import pandas as pd 
import scipy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set()
import thinkstats2
import thinkplot

pd.options.display.float_format = '{:.2f}'.format # change the display format of numbers

# %%
saffronart_df = pd.read_csv('updated_saffronart_dataset.csv', parse_dates=[1, 3, 9]) 

saffronart_df.head(5)
# Out:
#      artist birth_date birth_place death_date  artist_age  \
# 0  akhilesh 1956-01-01      Indore        NaT       63.00
# 1  akhilesh 1956-01-01      Indore        NaT       63.00
# 2  akhilesh 1956-01-01      Indore        NaT       63.00
# 3  akhilesh 1956-01-01      Indore        NaT       63.00
# 4  akhilesh 1956-01-01      Indore        NaT       63.00
#
#                              title  winning_bid  low_est  high_est  \
# 0              Divine Conversation      9000.00  5000.00   7000.00
# 1  In search of Untitled forms -II      1120.00  5000.00   6670.00
# 2      In Search of Untitled Lines      6186.00  6900.00   8625.00
# 3                          Magadhi      2400.00  5770.00   7695.00
# 4                         Untitled      2942.00  6735.00   8655.00
#
#   auction_date  category     style             size               medium  \
# 0   2019-06-01  painting  abstract   71.5 x 71.5 in   acrylic on canvas
# 1   2013-11-01  painting  abstract     32.5 x 44 in   acrylic on canvas
# 2   2013-08-01  painting       NaN       47 x 47 in   acrylic on canvas
# 3   2013-02-01  painting  abstract     33 x 44.5 in   acrylic on canvas
# 4   2013-02-01  painting  abstract       40 x 40 in   acrylic on canvas
#
#    area_or_vol  auction_dt_age
# 0      5112.25           63.00
# 1      1430.00           57.00
# 2      2209.00           57.00
# 3      1468.50           57.00
# 4      1600.00           57.00

# %% [markdown]
# # Category

# %%
cat_means = saffronart_df.groupby('category').mean() # mean prices by category 
cat_mean_p = pd.DataFrame(cat_means['winning_bid'])
cat_mean_p
# Out:
#                       winning_bid
# category
# ceramics                 10116.00
# chemical alterations      8420.00
# digital art               9398.90
# drawing                   8276.08
# installation             54903.54
# painting                 49133.30
# photography               5810.26
# print making              8544.54
# relief sculpture         14282.48
# sculpture                29420.97

# %%
def Cohen_effect_size(gr1, gr2):
    mean_diff = np.mean(gr1) - np.mean(gr2)
    
    n1, n2 = len(gr1), len(gr2) # drop na values
    
    var1, var2 = np.var(gr1), np.var(gr2)
    pooled_var = (n1*var1 + n2*var2)/(n1 + n2)
    
    d = mean_diff/ np.sqrt(pooled_var)
    
    return mean_diff, d

# %%
from collections import defaultdict

def mean_p_diff_by(df, var_name): # mean price difference
    groups = df.groupby(var_name)
    mean_diff_dict = defaultdict(list)

    for gr1_name, gr1 in groups:
        for gr2_name, gr2 in groups:
            mean_diff, d = Cohen_effect_size(gr1.winning_bid, gr2.winning_bid)
            mean_diff_dict[gr1_name].append((mean_diff, d))
            
        all_others = df.loc[df[var_name]!=gr1_name]
        mean_diff, d = Cohen_effect_size(gr1.winning_bid, all_others.winning_bid)
        mean_diff_dict[gr1_name].append((mean_diff, d))
        
    mean_diff_df = pd.DataFrame(mean_diff_dict)
        
    gr_names = list(groups.groups.keys())
    gr_names.append('all others')
    mean_diff_df[var_name] = gr_names
    mean_diff_df.set_index(var_name, inplace=True)
    
    return mean_diff_df

# %%
def highlight_diag(df):
    style_arr = np.full(df.shape, '', dtype='<U24') # create an empty np array of the same structure
    np.fill_diagonal(style_arr, 'background-color: pink')
    return pd.DataFrame(style_arr, index=df.index, columns=df.columns)

def format_pairwise_df(df, d_prec=2):
    # apply the decimal points precision for the df's values:
    df = df.applymap(lambda x: '{:.{prec}f}, {:.{prec}f}'.format(*x, prec=d_prec)) 
    
    return df.style.apply(highlight_diag, axis=None)

# %%
cat_mean_diff = mean_p_diff_by(saffronart_df, 'category')
format_pairwise_df(cat_mean_diff)
# Out:
# <style  type="text/css" >
#     #T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col0 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col1 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col2 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col3 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow4_col4 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow5_col5 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow6_col6 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow7_col7 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow8_col8 {
#             background-color:  pink;
#         }    #T_945bd6c0_bd82_11ea_be99_f834411ef69erow9_col9 {
#             background-color:  pink;
#         }</style><table id="T_945bd6c0_bd82_11ea_be99_f834411ef69e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ceramics</th>        <th class="col_heading level0 col1" >chemical alterations</th>        <th class="col_heading level0 col2" >digital art</th>        <th class="col_heading level0 col3" >drawing</th>        <th class="col_heading level0 col4" >installation</th>        <th class="col_heading level0 col5" >painting</th>        <th class="col_heading level0 col6" >photography</th>        <th class="col_heading level0 col7" >print making</th>        <th class="col_heading level0 col8" >relief sculpture</th>        <th class="col_heading level0 col9" >sculpture</th>    </tr>    <tr>        <th class="index_name level0" >category</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_945bd6c0_bd82_11ea_be99_f834411ef69elevel0_row0" class="row_heading level0 row0" >ceramics</th>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col0" class="data row0 col0" >0.00, 0.00</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col1" class="data row0 col1" >-1696.00, -0.46</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col2" class="data row0 col2" >-717.10, -0.04</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col3" class="data row0 col3" >-1839.92, -0.20</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col4" class="data row0 col4" >44787.54, 0.59</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col5" class="data row0 col5" >39017.30, 0.25</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col6" class="data row0 col6" >-4305.74, -0.11</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col7" class="data row0 col7" >-1571.46, -0.14</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col8" class="data row0 col8" >4166.48, 0.30</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow0_col9" class="data row0 col9" >19304.97, 0.32</td>
#             </tr>
#             <tr>
#                         <th id="T_945bd6c0_bd82_11ea_be99_f834411ef69elevel0_row1" class="row_heading level0 row1" >chemical alterations</th>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col0" class="data row1 col0" >1696.00, 0.46</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col1" class="data row1 col1" >0.00, 0.00</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col2" class="data row1 col2" >978.90, 0.06</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col3" class="data row1 col3" >-143.92, -0.02</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col4" class="data row1 col4" >46483.54, 0.65</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col5" class="data row1 col5" >40713.30, 0.27</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col6" class="data row1 col6" >-2609.74, -0.07</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col7" class="data row1 col7" >124.54, 0.01</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col8" class="data row1 col8" >5862.48, 0.45</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow1_col9" class="data row1 col9" >21000.97, 0.35</td>
#             </tr>
#             <tr>
#                         <th id="T_945bd6c0_bd82_11ea_be99_f834411ef69elevel0_row2" class="row_heading level0 row2" >digital art</th>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col0" class="data row2 col0" >717.10, 0.04</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col1" class="data row2 col1" >-978.90, -0.06</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col2" class="data row2 col2" >0.00, 0.00</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col3" class="data row2 col3" >-1122.83, -0.11</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col4" class="data row2 col4" >45504.64, 0.83</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col5" class="data row2 col5" >39734.40, 0.26</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col6" class="data row2 col6" >-3588.64, -0.10</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col7" class="data row2 col7" >-854.36, -0.07</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col8" class="data row2 col8" >4883.58, 0.29</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow2_col9" class="data row2 col9" >20022.07, 0.35</td>
#             </tr>
#             <tr>
#                         <th id="T_945bd6c0_bd82_11ea_be99_f834411ef69elevel0_row3" class="row_heading level0 row3" >drawing</th>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col0" class="data row3 col0" >1839.92, 0.20</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col1" class="data row3 col1" >143.92, 0.02</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col2" class="data row3 col2" >1122.83, 0.11</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col3" class="data row3 col3" >0.00, 0.00</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col4" class="data row3 col4" >46627.47, 2.26</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col5" class="data row3 col5" >40857.22, 0.28</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col6" class="data row3 col6" >-2465.81, -0.12</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col7" class="data row3 col7" >268.47, 0.03</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col8" class="data row3 col8" >6006.40, 0.62</td>
#                         <td id="T_945bd6c0_bd82_11ea_be99_f834411ef69erow3_col9" class="data row3 col9" >21144.89, 0.52</td>
#             </tr>
#             <tr>
#                         <th id="T_945bd6c0_bd82_11ea_be99_f834411ef69elevel0_row4" class="row_heading level0 row4" >installation</th>

# %% [markdown]
# **Instructions:** The first value of the tuple is the mean difference between the column category and the row category, i.e. $column - row$. The second value of the tuple is the Cohen effect size of the mean difference.

# %% [markdown]
# # Style

# %%
style_mean_diff = mean_p_diff_by(saffronart_df, 'style')
format_pairwise_df(style_mean_diff)
# Out:
# <style  type="text/css" >
#     #T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col0 {
#             background-color:  pink;
#         }    #T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col1 {
#             background-color:  pink;
#         }    #T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col2 {
#             background-color:  pink;
#         }    #T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col3 {
#             background-color:  pink;
#         }    #T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col4 {
#             background-color:  pink;
#         }    #T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col5 {
#             background-color:  pink;
#         }</style><table id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >abstract</th>        <th class="col_heading level0 col1" >calligraphy</th>        <th class="col_heading level0 col2" >figurative</th>        <th class="col_heading level0 col3" >landscape</th>        <th class="col_heading level0 col4" >still life</th>        <th class="col_heading level0 col5" >unknown</th>    </tr>    <tr>        <th class="index_name level0" >style</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row0" class="row_heading level0 row0" >abstract</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col0" class="data row0 col0" >0.00, 0.00</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col1" class="data row0 col1" >-59502.32, -0.28</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col2" class="data row0 col2" >-30515.78, -0.22</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col3" class="data row0 col3" >-6303.54, -0.03</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col4" class="data row0 col4" >-24625.49, -0.12</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow0_col5" class="data row0 col5" >-62818.72, -0.29</td>
#             </tr>
#             <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row1" class="row_heading level0 row1" >calligraphy</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col0" class="data row1 col0" >59502.32, 0.28</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col1" class="data row1 col1" >0.00, 0.00</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col2" class="data row1 col2" >28986.54, 0.25</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col3" class="data row1 col3" >53198.78, 0.35</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col4" class="data row1 col4" >34876.83, 0.31</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow1_col5" class="data row1 col5" >-3316.40, -0.93</td>
#             </tr>
#             <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row2" class="row_heading level0 row2" >figurative</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col0" class="data row2 col0" >30515.78, 0.22</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col1" class="data row2 col1" >-28986.54, -0.25</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col2" class="data row2 col2" >0.00, 0.00</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col3" class="data row2 col3" >24212.24, 0.20</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col4" class="data row2 col4" >5890.30, 0.05</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow2_col5" class="data row2 col5" >-32302.94, -0.28</td>
#             </tr>
#             <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row3" class="row_heading level0 row3" >landscape</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col0" class="data row3 col0" >6303.54, 0.03</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col1" class="data row3 col1" >-53198.78, -0.35</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col2" class="data row3 col2" >-24212.24, -0.20</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col3" class="data row3 col3" >0.00, 0.00</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col4" class="data row3 col4" >-18321.95, -0.13</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow3_col5" class="data row3 col5" >-56515.18, -0.37</td>
#             </tr>
#             <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row4" class="row_heading level0 row4" >still life</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col0" class="data row4 col0" >24625.49, 0.12</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col1" class="data row4 col1" >-34876.83, -0.31</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col2" class="data row4 col2" >-5890.30, -0.05</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col3" class="data row4 col3" >18321.95, 0.13</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col4" class="data row4 col4" >0.00, 0.00</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow4_col5" class="data row4 col5" >-38193.23, -0.34</td>
#             </tr>
#             <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row5" class="row_heading level0 row5" >unknown</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col0" class="data row5 col0" >62818.72, 0.29</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col1" class="data row5 col1" >3316.40, 0.93</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col2" class="data row5 col2" >32302.94, 0.28</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col3" class="data row5 col3" >56515.18, 0.37</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col4" class="data row5 col4" >38193.23, 0.34</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow5_col5" class="data row5 col5" >0.00, 0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69elevel0_row6" class="row_heading level0 row6" >all others</th>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow6_col0" class="data row6 col0" >42214.47, 0.37</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow6_col1" class="data row6 col1" >-21937.25, -0.19</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow6_col2" class="data row6 col2" >12418.74, 0.11</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow6_col3" class="data row6 col3" >33382.36, 0.29</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow6_col4" class="data row6 col4" >13314.25, 0.12</td>
#                         <td id="T_89e4fe68_bd81_11ea_b4d8_f834411ef69erow6_col5" class="data row6 col5" >-25247.99, -0.22</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Medium

# %%
med_counts = saffronart_df.groupby('medium').count() # counts of mediums
med_counts = pd.DataFrame(med_counts['artist'])
med_counts.rename(columns={'artist': 'count'}, inplace=True)

top_meds_ct = med_counts.nlargest(15, ['count']) # the top 15 mediums with highest counts
top_meds_ct
# Out:
#                                 count
# medium
#  oil on canvas                   2189
#  acrylic on canvas               1239
#  watercolour on paper             820
#  mixed media on paper             489
#  acrylic on paper                 243
#  ink on paper                     241
#  mixed media on canvas            214
#  pen and ink on paper             200
#  bronze                           171
#  gouache on paper                 167
#  pencil on paper                  154
#  charcoal on paper                129
#  oil on board                     128
#  watercolour and ink on paper     110
#  acrylic and oil on canvas        103

# %%
top_meds = top_meds_ct.index.to_list()
top_meds
# Out:
# [' oil on canvas ',
#  ' acrylic on canvas ',
#  ' watercolour on paper ',
#  ' mixed media on paper ',
#  ' acrylic on paper ',
#  ' ink on paper ',
#  ' mixed media on canvas ',
#  ' pen and ink on paper ',
#  ' bronze ',
#  ' gouache on paper ',
#  ' pencil on paper ',
#  ' charcoal on paper ',
#  ' oil on board ',
#  ' watercolour and ink on paper ',
#  ' acrylic and oil on canvas ']

# %%
top_meds_df = saffronart_df.loc[saffronart_df.medium.isin(top_meds)]
top_meds_df.reset_index(inplace=True, drop=True)
top_meds_df
# Out:
#              artist birth_date              birth_place death_date  \
# 0          akhilesh 1956-01-01                   Indore        NaT
# 1          akhilesh 1956-01-01                   Indore        NaT
# 2          akhilesh 1956-01-01                   Indore        NaT
# 3          akhilesh 1956-01-01                   Indore        NaT
# 4          akhilesh 1956-01-01                   Indore        NaT
# ...             ...        ...                      ...        ...
# 6592   jai zharotia 1945-01-01                New Delhi        NaT
# 6593        k h ara 1914-01-01                      NaN 1985-01-01
# 6594  gobardhan ash 1907-01-01                      NaN 1996-01-01
# 6595    s. dhanapal 1919-01-01                  Chennai 2000-05-15
# 6596     m f husain 1913-09-17  Pandharpur, Maharashtra 2011-06-09
#
#       artist_age                            title  winning_bid   low_est  \
# 0          63.00              Divine Conversation      9000.00   5000.00
# 1          63.00  In search of Untitled forms -II      1120.00   5000.00
# 2          63.00      In Search of Untitled Lines      6186.00   6900.00
# 3          63.00                          Magadhi      2400.00   5770.00
# 4          63.00                         Untitled      2942.00   6735.00
# ...          ...                              ...          ...       ...
# 6592       74.00                COMPOSITION, 1997      2326.00   6350.00
# 6593       71.00                         Untitled     16675.00  13500.00
# 6594       89.00                         Untitled          nan    800.00
# 6595       81.00                 Mother and Child          nan   7955.00
# 6596       98.00                         Untitled    340000.00 166670.00
#
#       high_est auction_date   category       style                size  \
# 0      7000.00   2019-06-01   painting    abstract      71.5 x 71.5 in
# 1      6670.00   2013-11-01   painting    abstract        32.5 x 44 in
# 2      8625.00   2013-08-01   painting         NaN          47 x 47 in
# 3      7695.00   2013-02-01   painting    abstract        33 x 44.5 in
# 4      8655.00   2013-02-01   painting    abstract          40 x 40 in
# ...        ...          ...        ...         ...                 ...
# 6592   9525.00   2015-07-01        NaN         NaN   43.5 in x 59.5 in
# 6593  15500.00   2007-12-01   painting  still life      21.5 x 29.5 in
# 6594   1200.00   2002-12-01   painting  figurative          11 x 18 in
# 6595  10230.00   2011-08-01  sculpture  figurative        18.5 x 13 in
# 6596 250000.00   2014-09-04   painting  figurative         118 x 46 in
#
#                    medium  area_or_vol  auction_dt_age
# 0      acrylic on canvas       5112.25           63.00
# 1      acrylic on canvas       1430.00           57.00
# 2      acrylic on canvas       2209.00           57.00
# 3      acrylic on canvas       1468.50           57.00
# 4      acrylic on canvas       1600.00           57.00
# ...                   ...          ...             ...
# 6592       oil on canvas       2588.25           70.00
# 6593    gouache on paper        634.25           71.00
# 6594    gouache on paper        198.00           89.00
# 6595              bronze        240.50           81.00
# 6596       oil on canvas       5428.00           98.00
#
# [6597 rows x 16 columns]

# %%
def subgr_mean_p_diff_by(big_df, small_df, var_name): # mean price difference
    groups = small_df.groupby(var_name)
    mean_diff_dict = defaultdict(list)

    for gr1_name, gr1 in groups:
        for gr2_name, gr2 in groups:
            mean_diff, d = Cohen_effect_size(gr1.winning_bid, gr2.winning_bid)
            mean_diff_dict[gr1_name].append((mean_diff, d))
            
        all_others = big_df.loc[big_df[var_name]!=gr1_name]
        mean_diff, d = Cohen_effect_size(gr1.winning_bid, all_others.winning_bid)
        mean_diff_dict[gr1_name].append((mean_diff, d))
        
    mean_diff_df = pd.DataFrame(mean_diff_dict)
        
    gr_names = list(groups.groups.keys())
    gr_names.append('all others')
    mean_diff_df[var_name] = gr_names
    mean_diff_df.set_index(var_name, inplace=True)
    
    return mean_diff_df

# %%
med_mean_diff = subgr_mean_p_diff_by(saffronart_df, top_meds_df, 'medium')
format_pairwise_df(med_mean_diff)
# Out:
# <style  type="text/css" >
#     #T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col0 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col1 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow2_col2 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow3_col3 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow4_col4 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow5_col5 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow6_col6 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow7_col7 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow8_col8 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow9_col9 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow10_col10 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow11_col11 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow12_col12 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow13_col13 {
#             background-color:  pink;
#         }    #T_669884dc_bd86_11ea_9da7_f834411ef69erow14_col14 {
#             background-color:  pink;
#         }</style><table id="T_669884dc_bd86_11ea_9da7_f834411ef69e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" > acrylic and oil on canvas </th>        <th class="col_heading level0 col1" > acrylic on canvas </th>        <th class="col_heading level0 col2" > acrylic on paper </th>        <th class="col_heading level0 col3" > bronze </th>        <th class="col_heading level0 col4" > charcoal on paper </th>        <th class="col_heading level0 col5" > gouache on paper </th>        <th class="col_heading level0 col6" > ink on paper </th>        <th class="col_heading level0 col7" > mixed media on canvas </th>        <th class="col_heading level0 col8" > mixed media on paper </th>        <th class="col_heading level0 col9" > oil on board </th>        <th class="col_heading level0 col10" > oil on canvas </th>        <th class="col_heading level0 col11" > pen and ink on paper </th>        <th class="col_heading level0 col12" > pencil on paper </th>        <th class="col_heading level0 col13" > watercolour and ink on paper </th>        <th class="col_heading level0 col14" > watercolour on paper </th>    </tr>    <tr>        <th class="index_name level0" >medium</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_669884dc_bd86_11ea_9da7_f834411ef69elevel0_row0" class="row_heading level0 row0" > acrylic and oil on canvas </th>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col0" class="data row0 col0" >0.00, 0.00</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col1" class="data row0 col1" >20609.32, 0.15</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col2" class="data row0 col2" >-17167.79, -0.48</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col3" class="data row0 col3" >-10546.72, -0.26</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col4" class="data row0 col4" >-22514.62, -0.64</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col5" class="data row0 col5" >-10003.61, -0.14</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col6" class="data row0 col6" >-22710.58, -0.77</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col7" class="data row0 col7" >-10417.32, -0.27</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col8" class="data row0 col8" >-21092.91, -0.83</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col9" class="data row0 col9" >55041.12, 0.58</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col10" class="data row0 col10" >52265.54, 0.24</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col11" class="data row0 col11" >-24096.42, -0.79</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col12" class="data row0 col12" >-24521.50, -0.75</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col13" class="data row0 col13" >-22297.45, -0.61</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow0_col14" class="data row0 col14" >-19642.49, -0.90</td>
#             </tr>
#             <tr>
#                         <th id="T_669884dc_bd86_11ea_9da7_f834411ef69elevel0_row1" class="row_heading level0 row1" > acrylic on canvas </th>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col0" class="data row1 col0" >-20609.32, -0.15</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col1" class="data row1 col1" >0.00, 0.00</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col2" class="data row1 col2" >-37777.11, -0.28</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col3" class="data row1 col3" >-31156.04, -0.23</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col4" class="data row1 col4" >-43123.94, -0.31</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col5" class="data row1 col5" >-30612.94, -0.22</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col6" class="data row1 col6" >-43319.91, -0.32</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col7" class="data row1 col7" >-31026.65, -0.23</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col8" class="data row1 col8" >-41702.23, -0.33</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col9" class="data row1 col9" >34431.80, 0.24</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col10" class="data row1 col10" >31656.21, 0.16</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col11" class="data row1 col11" >-44705.74, -0.33</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col12" class="data row1 col12" >-45130.82, -0.33</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col13" class="data row1 col13" >-42906.77, -0.31</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow1_col14" class="data row1 col14" >-40251.81, -0.35</td>
#             </tr>
#             <tr>
#                         <th id="T_669884dc_bd86_11ea_9da7_f834411ef69elevel0_row2" class="row_heading level0 row2" > acrylic on paper </th>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow2_col0" class="data row2 col0" >17167.79, 0.48</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow2_col1" class="data row2 col1" >37777.11, 0.28</td>
#                         <td id="T_669884dc_bd86_11ea_9da7_f834411ef69erow2_col2" class="data row2 col2" >0.00, 0.00</td>

# %%
# top 5:

top5_meds = med_counts.nlargest(5, ['count']).index.to_list()
top5_meds_df = saffronart_df.loc[saffronart_df.medium.isin(top5_meds)]

top5_mean_diff = subgr_mean_p_diff_by(saffronart_df, top5_meds_df, 'medium')
format_pairwise_df(top5_mean_diff)
# Out:
# <style  type="text/css" >
#     #T_72f44dfa_bd86_11ea_b035_f834411ef69erow0_col0 {
#             background-color:  pink;
#         }    #T_72f44dfa_bd86_11ea_b035_f834411ef69erow1_col1 {
#             background-color:  pink;
#         }    #T_72f44dfa_bd86_11ea_b035_f834411ef69erow2_col2 {
#             background-color:  pink;
#         }    #T_72f44dfa_bd86_11ea_b035_f834411ef69erow3_col3 {
#             background-color:  pink;
#         }    #T_72f44dfa_bd86_11ea_b035_f834411ef69erow4_col4 {
#             background-color:  pink;
#         }</style><table id="T_72f44dfa_bd86_11ea_b035_f834411ef69e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" > acrylic on canvas </th>        <th class="col_heading level0 col1" > acrylic on paper </th>        <th class="col_heading level0 col2" > mixed media on paper </th>        <th class="col_heading level0 col3" > oil on canvas </th>        <th class="col_heading level0 col4" > watercolour on paper </th>    </tr>    <tr>        <th class="index_name level0" >medium</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72f44dfa_bd86_11ea_b035_f834411ef69elevel0_row0" class="row_heading level0 row0" > acrylic on canvas </th>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow0_col0" class="data row0 col0" >0.00, 0.00</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow0_col1" class="data row0 col1" >-37777.11, -0.28</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow0_col2" class="data row0 col2" >-41702.23, -0.33</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow0_col3" class="data row0 col3" >31656.21, 0.16</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow0_col4" class="data row0 col4" >-40251.81, -0.35</td>
#             </tr>
#             <tr>
#                         <th id="T_72f44dfa_bd86_11ea_b035_f834411ef69elevel0_row1" class="row_heading level0 row1" > acrylic on paper </th>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow1_col0" class="data row1 col0" >37777.11, 0.28</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow1_col1" class="data row1 col1" >0.00, 0.00</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow1_col2" class="data row1 col2" >-3925.12, -0.20</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow1_col3" class="data row1 col3" >69433.33, 0.32</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow1_col4" class="data row1 col4" >-2474.70, -0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_72f44dfa_bd86_11ea_b035_f834411ef69elevel0_row2" class="row_heading level0 row2" > mixed media on paper </th>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow2_col0" class="data row2 col0" >41702.23, 0.33</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow2_col1" class="data row2 col1" >3925.12, 0.20</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow2_col2" class="data row2 col2" >0.00, 0.00</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow2_col3" class="data row2 col3" >73358.45, 0.36</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow2_col4" class="data row2 col4" >1450.42, 0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_72f44dfa_bd86_11ea_b035_f834411ef69elevel0_row3" class="row_heading level0 row3" > oil on canvas </th>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow3_col0" class="data row3 col0" >-31656.21, -0.16</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow3_col1" class="data row3 col1" >-69433.33, -0.32</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow3_col2" class="data row3 col2" >-73358.45, -0.36</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow3_col3" class="data row3 col3" >0.00, 0.00</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow3_col4" class="data row3 col4" >-71908.02, -0.37</td>
#             </tr>
#             <tr>
#                         <th id="T_72f44dfa_bd86_11ea_b035_f834411ef69elevel0_row4" class="row_heading level0 row4" > watercolour on paper </th>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow4_col0" class="data row4 col0" >40251.81, 0.35</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow4_col1" class="data row4 col1" >2474.70, 0.14</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow4_col2" class="data row4 col2" >-1450.42, -0.10</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow4_col3" class="data row4 col3" >71908.02, 0.37</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow4_col4" class="data row4 col4" >0.00, 0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_72f44dfa_bd86_11ea_b035_f834411ef69elevel0_row5" class="row_heading level0 row5" >all others</th>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow5_col0" class="data row5 col0" >23499.83, 0.20</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow5_col1" class="data row5 col1" >-17091.79, -0.15</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow5_col2" class="data row5 col2" >-21474.27, -0.19</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow5_col3" class="data row5 col3" >63278.16, 0.55</td>
#                         <td id="T_72f44dfa_bd86_11ea_b035_f834411ef69erow5_col4" class="data row5 col4" >-20584.61, -0.18</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Instructions:** The first value of the tuple is the mean difference between the column medium and the row medium, i.e. $column - row$. The second value of the tuple is the Cohen effect size of the mean difference.

# %% [markdown]
# # Artist deceased or not

# %%
saffronart_df['deceased'] = ~saffronart_df.death_date.isnull()
saffronart_df['deceased'] = saffronart_df.deceased.astype(int) # convert to binary

saffronart_df.tail(5)
# Out:
#                  artist birth_date                            birth_place  \
# 12416       atul dodiya 1959-01-20                                 Mumbai
# 12417        m f husain 1913-09-17                Pandharpur, Maharashtra
# 12418  nasreen mohamedi 1937-01-01        Karachi India (now in Pakistan)
# 12419     baiju parthan 1956-01-01                       Kottayam, Kerala
# 12420   thota vaikuntam 1942-01-01  Boorugupali Karimnagar Andhra Pradesh
#
#       death_date  artist_age              title  winning_bid   low_est  \
# 12416        NaT       60.00        Walking Man     30475.00  20000.00
# 12417 2011-06-09       98.00           Untitled    340000.00 166670.00
# 12418 1990-01-01       53.00           Untitled     11352.00   8700.00
# 12419        NaT       63.00  Process - (Fruit)      4426.00   2460.00
# 12420        NaT       77.00           Untitled     26554.00  11115.00
#
#        high_est auction_date      category       style             size  \
# 12416  26670.00   2010-09-01      painting  figurative       21 x 21 in
# 12417 250000.00   2014-09-04      painting  figurative      118 x 46 in
# 12418  10870.00   2011-09-01       drawing    abstract   10.5 x 13.5 in
# 12419   4100.00   2015-04-07  print making  still life   36.5 x 34.5 in
# 12420  13335.00   2010-09-01      painting  figurative       36 x 24 in
#
#                                             medium  area_or_vol  \
# 12416                                oil on paper        441.00
# 12417                               oil on canvas       5428.00
# 12418                ink and pencil on card paper        141.75
# 12419   archival ink on hahnemuhle archival paper       1259.25
# 12420                     acrylic on canvas board        864.00
#
#        auction_dt_age  deceased
# 12416           51.00         0
# 12417           98.00         1
# 12418           53.00         1
# 12419           59.00         0
# 12420           68.00         0

# %%
deceased_means = saffronart_df.groupby('deceased').mean() 
deceased_mean_p = pd.DataFrame(deceased_means['winning_bid']) # mean prices by whether the artist is deceased or not 
deceased_mean_p.rename({0: 'No', 1: 'Yes'}, axis='index')
# Out:
#           winning_bid
# deceased
# No           17137.68
# Yes          50695.99

# %%
dead = saffronart_df.loc[saffronart_df.deceased==1]
alive = saffronart_df.loc[saffronart_df.deceased==0]

deceased_mean_diff = Cohen_effect_size(dead.winning_bid, alive.winning_bid)
print('Price mean difference bw living & deceased artists: {:.2f}'.format(deceased_mean_diff[0]))
print('Cohen effect size of the mean difference: {:.2f}'.format(deceased_mean_diff[1]))
# Out:
# Price mean difference bw living & deceased artists: 33558.31
# Cohen effect size of the mean difference: 0.29

# %%
dec_price_formula = 'winning_bid ~ C(deceased)' 
dec_price_model = smf.ols(dec_price_formula, data=saffronart_df) 
dec_price_results = dec_price_model.fit()

dec_price_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            winning_bid   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     205.9
# Date:                Fri, 03 Jul 2020   Prob (F-statistic):           3.03e-46
# Time:                        21:12:20   Log-Likelihood:            -1.3659e+05
# No. Observations:               10456   AIC:                         2.732e+05
# Df Residuals:                   10454   BIC:                         2.732e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         1.714e+04   1383.625     12.386      0.000    1.44e+04    1.98e+04
# C(deceased)[T.1]  3.356e+04   2338.945     14.348      0.000     2.9e+04    3.81e+04
# ==============================================================================
# Omnibus:                    21187.807   Durbin-Watson:                   1.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         75360128.203
# Skew:                          16.754   Prob(JB):                         0.00
# Kurtosis:                     417.553   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
